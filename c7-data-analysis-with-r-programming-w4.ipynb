# %% [markdown]
# # Course 7 - Data Analysis with R Programming

# %% [markdown]
# ## Week 4 - Create data visualizations in R

# %% [markdown]
# ### Visualization basics in R and tidyverse

# %% [markdown]
# To install and load the packages needed:

# %%
install.packages("ggplot2")
install.packages("palmerpenguins")
library(ggplot2)
library(palmerpenguins)

# %% [markdown]
# Load the data and see the first few rows:

# %%
data(penguins)
head(penguins)
# Out:
#   species island    bill_length_mm bill_depth_mm flipper_length_mm body_mass_g
# 1 Adelie  Torgersen 39.1           18.7          181               3750
# 2 Adelie  Torgersen 39.5           17.4          186               3800
# 3 Adelie  Torgersen 40.3           18.0          195               3250
# 4 Adelie  Torgersen   NA             NA           NA                 NA
# 5 Adelie  Torgersen 36.7           19.3          193               3450
# 6 Adelie  Torgersen 39.3           20.6          190               3650
#   sex    year
# 1 male   2007
# 2 female 2007
# 3 female 2007
# 4 NA     2007
# 5 female 2007
# 6 male   2007

# %% [markdown]
# To create the plot:
# ggplot(data = penguins) -- to begin a plot and choose the data set
# geom_point() -- uses points to create a scatter plot
# mapping=aes(x=flipper_length_mm, y=body_mass_g) -- geom function requires mapping, how variables are mapped to visual properties

# %%
ggplot(data = penguins) + geom_point(mapping=aes(x=flipper_length_mm, y=body_mass_g))
# Out:
# Warning message:
# "Removed 2 rows containing missing values (geom_point)."
# plot without title

# %% [markdown]
# Can also be run with the following:

# %%
ggplot(data = penguins, mapping = aes(x = flipper_length_mm, y = body_mass_g)) +  geom_point()
# Out:
# Warning message:
# "Removed 2 rows containing missing values (geom_point)."
# plot without title

# %% [markdown]
# ### Getting started with ggplot()

# %% [markdown]
# Trying a different pair of variables:

# %%
ggplot(data=penguins) + geom_point(mapping=aes(x=bill_length_mm,y=bill_depth_mm))
# Out:
# Warning message:
# "Removed 2 rows containing missing values (geom_point)."
# plot without title

# %% [markdown]
# To learn more about functions

# %%
?aes
# Out:
# aes                  package:ggplot2                   R Documentation
#
# s
#
# n:
#
#      Aesthetic mappings describe how variables in the data are mapped
#      to visual properties (aesthetics) of geoms. Aesthetic mappings can
#      be set in 'ggplot()' and in individual layers.
#
# e:
#
#      aes(x, y, ...)
#
# s:
#
# x, y, ...: List of name-value pairs in the form 'aesthetic = variable'
#           describing which variables in the layer data should be mapped
#           to which aesthetics used by the paired geom/stat. The
#           expression 'variable' is evaluated within the layer data, so
#           there is no need to refer to the original dataset (i.e., use
#           'ggplot(df, aes(variable))' instead of 'ggplot(df,
#           aes(df$variable))'). The names for x and y aesthetics are
#           typically omitted because they are so common; all other
#           aesthetics must be named.
#
# s:
#
# ...

# %% [markdown]
# ## Week 4 - Explore aesthetics in analysis

# %% [markdown]
# ### Enhancing visualizations in R

# %% [markdown]
# Adding in the color function:

# %%
ggplot(data=penguins) + geom_point(mapping=aes(x=flipper_length_mm,y=body_mass_g, color=species))
# Out:
# Warning message:
# "Removed 2 rows containing missing values (geom_point)."
# plot without title

# %% [markdown]
# Adding in the shape function:

# %%
ggplot(data=penguins) + geom_point(mapping=aes(x=flipper_length_mm,y=body_mass_g, shape=species))
# Out:
# Warning message:
# "Removed 2 rows containing missing values (geom_point)."
# plot without title

# %% [markdown]
# Adding in the color, shape and size functions:

# %%
ggplot(data=penguins) + geom_point(mapping=aes(x=flipper_length_mm,y=body_mass_g, shape=species, color=species, size=species))
# Out:
# Warning message:
# "Using size for a discrete variable is not advised."
# Warning message:
# "Removed 2 rows containing missing values (geom_point)."
# plot without title

# %% [markdown]
# Using the alpha function:

# %%
ggplot(data=penguins) + geom_point(mapping=aes(x=flipper_length_mm,y=body_mass_g, alpha=species))
# Out:
# Warning message:
# "Using alpha for a discrete variable is not advised."
# Warning message:
# "Removed 2 rows containing missing values (geom_point)."
# plot without title

# %% [markdown]
# The code within the aes function tells R how to map aesthetics to variables. Code outside of the aes function changes the appearance of the overall plot.

# %%
ggplot(data=penguins) + geom_point(mapping=aes(x=flipper_length_mm,y=body_mass_g), color="purple")
# Out:
# Warning message:
# "Removed 2 rows containing missing values (geom_point)."
# plot without title

# %% [markdown]
# ### Doing more with ggplot

# %% [markdown]
# Using geom_smooth():

# %%
ggplot(data=penguins) + geom_smooth(mapping=aes(x=flipper_length_mm,y=body_mass_g))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
#
# Warning message:
# "Removed 2 rows containing non-finite values (stat_smooth)."
# plot without title

# %% [markdown]
# Adding two layers:

# %%
ggplot(data=penguins) + geom_smooth(mapping=aes(x=flipper_length_mm,y=body_mass_g)) + geom_point(mapping=aes(x=flipper_length_mm,y=body_mass_g))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
#
# Warning message:
# "Removed 2 rows containing non-finite values (stat_smooth)."
# Warning message:
# "Removed 2 rows containing missing values (geom_point)."
# plot without title

# %% [markdown]
# Adding multiple lines, much like different colours earlier:

# %%
ggplot(data=penguins) + geom_smooth(mapping=aes(x=flipper_length_mm,y=body_mass_g,linetype=species))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
#
# Warning message:
# "Removed 2 rows containing non-finite values (stat_smooth)."
# plot without title

# %% [markdown]
# geom_jitter():

# %%
ggplot(data=penguins) + geom_jitter(mapping=aes(x=flipper_length_mm,y=body_mass_g))
# Out:
# Warning message:
# "Removed 2 rows containing missing values (geom_point)."
# plot without title

# %% [markdown]
# Using geom_bar(). R automatically counts how many times the x value appears in the data, so no y variable is needed to be supplied.

# %%
ggplot(data=diamonds) + geom_bar(mapping=aes(x=cut))
# Out:
# plot without title

# %% [markdown]
# Adding color to geom_bar():

# %%
ggplot(data=diamonds) + geom_bar(mapping=aes(x=cut,color=cut))
# Out:
# plot without title

# %% [markdown]
# Adding fill to geom_bar():

# %%
ggplot(data=diamonds) + geom_bar(mapping=aes(x=cut,fill=cut))
# Out:
# plot without title

# %% [markdown]
# Using fill on a different variable to create a stacked bar chart:

# %%
ggplot(data=diamonds) + geom_bar(mapping=aes(x=cut,fill=clarity))
# Out:
# plot without title

# %% [markdown]
# ### Aesthetics and facets

# %% [markdown]
# Using facet_wrap() to put each value of a variable on a different plot

# %%
ggplot(data=penguins) + geom_point(mapping=aes(x=flipper_length_mm,y=body_mass_g,color=species)) + facet_wrap(~species)
# Out:
# Warning message:
# "Removed 2 rows containing missing values (geom_point)."
# plot without title

# %%
ggplot(data=diamonds) + geom_bar(mapping=aes(x=color,fill=cut)) + facet_wrap(~cut)
# Out:
# plot without title

# %% [markdown]
# Using facet_grid to split the plots into a grid, with one plot for combination of the two variables specified:

# %%
ggplot(data=penguins) + geom_point(mapping=aes(x=flipper_length_mm,y=body_mass_g,color=species)) + facet_grid(sex~species)
# Out:
# Warning message:
# "Removed 2 rows containing missing values (geom_point)."
# plot without title

# %%
ggplot(data=penguins) + geom_point(mapping=aes(x=flipper_length_mm,y=body_mass_g,color=species)) + facet_grid(~sex)
# Out:
# Warning message:
# "Removed 2 rows containing missing values (geom_point)."
# plot without title

# %% [markdown]
# ## Week 4 - Annotate and save visualizations

# %% [markdown]
# ### Annotation layer

# %% [markdown]
# To add a title:

# %%
ggplot(data=penguins) + geom_point(mapping=aes(x=flipper_length_mm,y=body_mass_g,color=species)) + labs(title="Palmer Penguins: Body Mass vs. Flipper Length")
# Out:
# Warning message:
# "Removed 2 rows containing missing values (geom_point)."
# plot without title

# %% [markdown]
# To add a subtitle:

# %%
ggplot(data=penguins) + geom_point(mapping=aes(x=flipper_length_mm,y=body_mass_g,color=species)) + labs(title="Palmer Penguins: Body Mass vs. Flipper Length", subtitle="Sample of Three Penguin Species")
# Out:
# Warning message:
# "Removed 2 rows containing missing values (geom_point)."
# plot without title

# %% [markdown]
# To add a caption:

# %%
ggplot(data=penguins) + geom_point(mapping=aes(x=flipper_length_mm,y=body_mass_g,color=species)) + labs(title="Palmer Penguins: Body Mass vs. Flipper Length", subtitle="Sample of Three Penguin Species",caption="Data collected by Dr. Kristen Gorman")
# Out:
# Warning message:
# "Removed 2 rows containing missing values (geom_point)."
# plot without title

# %% [markdown]
# To add an annotation and customise it:

# %%
ggplot(data=penguins) + geom_point(mapping=aes(x=flipper_length_mm,y=body_mass_g,color=species)) + labs(title="Palmer Penguins: Body Mass vs. Flipper Length", subtitle="Sample of Three Penguin Species",caption="Data collected by Dr. Kristen Gorman") + annotate("text", x=220, y=3500, label="The Gentoos are the largest", color="purple", fontface="bold", size=4.5, angle=25)
# Out:
# Warning message:
# "Removed 2 rows containing missing values (geom_point)."
# plot without title

# %% [markdown]
# To store code as a variable, then use it with more layers:

# %%
p <- ggplot(data=penguins) + geom_point(mapping=aes(x=flipper_length_mm,y=body_mass_g,color=species)) + labs(title="Palmer Penguins: Body Mass vs. Flipper Length", subtitle="Sample of Three Penguin Species",caption="Data collected by Dr. Kristen Gorman") 
p + annotate("text", x=220, y=3500, label="The Gentoos are the largest", color="purple", fontface="bold", size=4.5, angle=25)
# Out:
# Warning message:
# "Removed 2 rows containing missing values (geom_point)."
# plot without title

# %% [markdown]
# ### Saving your visualizations

# %% [markdown]
# Using ggsave to save the last plot:

# %%
ggplot(data=penguins) + geom_point(mapping=aes(x=flipper_length_mm,y=body_mass_g, color=species))
ggsave("Three Penguin Species.png")
# Out:
# Warning message:
# "Removed 2 rows containing missing values (geom_point)."
# Saving 6.67 x 6.67 in image
#
# Warning message:
# "Removed 2 rows containing missing values (geom_point)."
# plot without title
